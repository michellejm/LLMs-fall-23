# %% [markdown]
# <a href="https://colab.research.google.com/github/michellejm/LLMs-fall-23/blob/main/testing_pythia_prompts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ❗**WARNING**❗
#
# This lab will be slow if you do it locally. If you bought the GPU's for this class, you should still have plenty of credits left over. Use any size GPU for this.

# %% [markdown]
# ## Lab to test prompts
# LLM's and ChatGPT | Fall 2023 | McSweeney | CUNY Graduate Center
#
# **Due:** NA
#
#
# ### Background
# The purpose of this lab is to see how to call models from Hugging Face using the API. The purpose is to interact with models that are hosted on Hugging Face and programmatically generate results.
#
#
# ### Notes
# We'll use [the Pythia model](https://huggingface.co/EleutherAI/pythia-1.4b) because it's intended for research and has featured prominently in both in researching bias and fine tuning.

# %%
#same library we've been using
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 20.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 28.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 28.3 MB/s eta 0:00:00
# ...

# %%
# the model type we will be using
from transformers import GPTNeoXForCausalLM
# the Autotokenizer detects the tokenization of the original model
# this will be used to tokenize the input.
from transformers import AutoTokenizer

# %% [markdown]
# If you want to see how this model performs at earlier epochs (even epoch 1), feel free to change the step value.
#
# The step options are under 'Intended Use' in the [Pythia Model Card](https://huggingface.co/EleutherAI/pythia-1.4b?text=My+name+is+Maria+and+my+main)
#
# Here we're just calling the model with its name and them specifying the revision step.

# %%
mystep = 'step143000'

model = GPTNeoXForCausalLM.from_pretrained(
  "EleutherAI/pythia-1.4b",
  revision= mystep,
  cache_dir="./pythia-1.4b/"+mystep+"/",
)

tokenizer = AutoTokenizer.from_pretrained(
  "EleutherAI/pythia-1.4b",
  revision= mystep,
  cache_dir="./pythia-1.4b/"+mystep+"/",
)

# %% [markdown]
# Now try it out. Change the prompt as many times as you like. Remember that this is a completion model, so it can finish your sentence, but might not be able to write you email.

# %%
inputs = tokenizer("Hello, my name is Sarah and my goal is", return_tensors="pt")
tokens = model.generate(**inputs)
tokenizer.decode(tokens[0])
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# 'Hello, my name is Sarah and my goal is to become a successful business owner. I am a'

# %% [markdown]
# Now you can imagine if you wanted to test a bunch of different names with varying degrees of "genderedness". You could make a list of names and just loop through them, collecting their responses as you go.
