# %% [markdown]
# ## Wordvectors lab
# LLM's and ChatGPT | Fall 2023 | McSweeney | CUNY Graduate Center
#
# **Due:** October 8
#
#
# ### Background
# The purpose of this lab is to explore the process of transforming words into numerical representations, and then understanding those values spatially. By the end of this lab (and corresponding lecture), you should be comfortable with the fact that computers transform text into numbers based on the context in which they appear.
#
# There are **two** parts to this lab:
#
# * **Part 1**: We'll train our own vectors on a very small corpus to understand vector similarity in a contextualized setting. We'll explore what vectors look like, how words are related, and the vocabulary of a model.
# * **Part 2**: GloVe word embeddings. GloVe is an unsupervised learning algorithm to calculate the vectors of the words in a corpus. We will use the pre-trained version that comes from Wikipedia articles. You can find [more about the GloVe vectors here](https://nlp.stanford.edu/projects/glove/). The goal of this section is to understand general word embeddings as trained on a very large corpus.
#
#
#
#
# #### Notes
# You are not expected to understand the math or the code. We are using dimensionality reduction, which has a lot of uses including visualization and optimizing performance efficiency. For us, we are using dimensionality reduction for visualization. Word vectors create very large matrices. We can only visualize things on 2 or 3 dimension. So we reduce the dimensions.
#
# #### The book in the file
# [From wikipedia:](https://en.wikipedia.org/wiki/Catching_Fire) Catching Fire is a 2009 dystopian young adult fiction novel by the American novelist Suzanne Collins, the second book in The Hunger Games series. As the sequel to the 2008 bestseller The Hunger Games, it continues the story of Katniss Everdeen and the post-apocalyptic nation of Panem. Following the events of the previous novel, a rebellion against the oppressive Capitol has begun, and Katniss and fellow tribute Peeta Mellark are forced to return to the arena in a special edition of the Hunger Games.

# %% [markdown]
# * `re` is the regular expression library
# * `gensim` is for representing documents as vectors. It's the library built for making word vectors.

# %% [markdown]
# ## Part 1: Gensim

# %%
import re
import nltk
import numpy as np
import matplotlib.pyplot as plt
import random

from gensim.models import Word2Vec

from sklearn.decomposition import IncrementalPCA   
from sklearn.manifold import TSNE

# %% [markdown]
# Load a file and replace the markup characters

# %%
# read a file you have stored locally
# I added the Hunger Games for simplicity
file = open("hunger_games.txt", 'r').read()

# first, remove unwanted new line and tab characters from the text
for char in ["\n", "\r", "\d", "\t"]:
    file = file.replace(char, " ")

# check
print(file[:100])
# Out:
# The Second Book of THE HUNGER GAMES     New York Times Bestsel ling Author   SUZHNNE  COLLINS     PA

# %% [markdown]
# Clean the text a little bit (tokenize, lowercase)

# %%
# this is simplified for demonstration
def sample_clean_text(text: str):
    # step 1: tokenize the text into sentences
    sentences = nltk.sent_tokenize(text)

    # step 2: tokenize each sentence into words
    tokenized_sentences = [nltk.word_tokenize(sent) for sent in sentences]

    # step 3: convert each word to lowercase
    tokenized_text = [[word.lower() for word in sent] for sent in tokenized_sentences]
    
    # return your tokens
    return tokenized_text

# call the function
tokens = sample_clean_text(text = file)

# check
print(tokens[:10])
# Out:
# [['the', 'second', 'book', 'of', 'the', 'hunger', 'games', 'new', 'york', 'times', 'bestsel', 'ling', 'author', 'suzhnne', 'collins', 'parti', '``', 'the', 'spark', "''", '2', '|', 'p', 'a', 'g', 'e', 'catching', 'fire', '-', 'suzanne', 'collins', 'i', 'clasp', 'the', 'flask', 'between', 'my', 'hands', 'even', 'though', 'the', 'warmth', 'from', 'the', 'tea', 'has', 'long', 'since', 'leached', 'into', 'the', 'frozen', 'air', '.'], ['my', 'muscles', 'are', 'clenched', 'tight', 'against', 'the', 'cold', '.'], ['if', 'a', 'pack', 'of', 'wild', 'dogs', 'were', 'to', 'appear', 'at', 'this', 'moment', ',', 'the', 'odds', 'of', 'scaling', 'a', 'tree', 'before', 'they', 'attacked', 'are', 'not', 'in', 'my', 'favor', '.'], ['i', 'should', 'get', 'up', ',', 'move', 'around', ',', 'and', 'work', 'the', 'stiffness', 'from', 'my', 'limbs', '.'], ['but', 'instead', 'i', 'sit', ',', 'as', 'motionless', 'as', 'the', 'rock', 'beneath', 'me', ',', 'while', 'the', 'dawn', 'begins', 'to', 'lighten', 'the', 'woods', '.'], ['i', 'ca', "n't", 'fight', 'the', 'sun', '.'], ['i', 'can', 'only', 'watch', 'helplessly', 'as', 'it', 'drags', 'me', 'into', 'a', 'day', 'that', 'i', "'ve", 'been', 'dreading', 'for', 'months', '.'], ['by', 'noon', 'they', 'will', 'all', 'be', 'at', 'my', 'new', 'house', 'in', 'the', 'victor', "'s", 'village', '.'], ['the', 'reporters', ',', 'the', 'camera', 'crews', ',', 'even', 'effie', 'trinket', ',', 'my', 'old', 'escort', ',', 'will', 'have', 'made', 'their', 'way', 'to', 'district', '12', 'from', 'the', 'capitol', '.'], ['i', 'wonder', 'if', 'effie', 'will', 'still', 'be', 'wearing', 'that', 'silly', 'pink', 'wig', ',', 'or', 'if', 'she', "'ll", 'be', 'sporting', 'some', 'other', 'unnatural', 'color', 'especially', 'for', 'the', 'victory', 'tour', '.']]

# %% [markdown]
# Establish the [word2vec ](https://www.tensorflow.org/text/tutorials/word2vec#:~:text=word2vec%20is%20not%20a%20singular,downstream%20natural%20language%20processing%20tasks.)model. We've given it our list of tokens. We said that for each token, we want to define it in the context of 100 words.
#
# This means that each vector will have 100 numbers in it representing the relationship between this word and 100 others.
#
# The larger this number is, the better the model. The smaller the number, the worse the model.

# %%
model = Word2Vec(tokens,vector_size=100)

# %% [markdown]
# Now explore the entire vocabulary (note that only 1000 are represented because of the interface -- there are far more words in the vocab). Use this for ideas in the next section

# %%
model.wv.key_to_index
# Out:
# {'.': 0,
#  ',': 1,
#  'the': 2,
#  'i': 3,
#  'to': 4,
#  'and': 5,
#  'a': 6,
#  'of': 7,
#  '``': 8,
#  "''": 9,
#  "'s": 10,
#  'it': 11,
#  'in': 12,
#  'my': 13,
#  'he': 14,
#  'that': 15,
#  'but': 16,
#  "n't": 17,
#  'me': 18,
#  '?': 19,
#  'on': 20,
#  'with': 21,
#  'you': 22,
#  'we': 23,
#  'for': 24,
#  'is': 25,
#  'peeta': 26,
#  'his': 27,
#  'be': 28,
#  'as': 29,
#  'do': 30,
#  'at': 31,
#  'have': 32,
#  'they': 33,
#  'says': 34,
#  'from': 35,
#  'out': 36,
#  'what': 37,
#  'him': 38,
#  'so': 39,
#  'her': 40,
#  'up': 41,
#  'can': 42,
#  'fire': 43,
#  'was': 44,
#  'she': 45,
#  'not': 46,
#  'this': 47,
#  'no': 48,
#  'if': 49,
#  'there': 50,
#  'catching': 51,
#  'are': 52,
#  'one': 53,
#  'collins': 54,
#  'all': 55,
#  '-': 56,
#  'suzanne': 57,
#  'p': 58,
#  'g': 59,
#  'e': 60,
#  '|': 61,
#  "'m": 62,
#  'know': 63,
#  'say': 64,
#  'about': 65,
#  'into': 66,
#  'when': 67,
#  'us': 68,
#  'haymitch': 69,
#  'just': 70,
#  'finnick': 71,
#  'will': 72,
#  'them': 73,
#  'back': 74,
#  'has': 75,
#  'think': 76,
#  'then': 77,
#  'by': 78,
#  'see': 79,
#  'an': 80,
#  "'re": 81,
#  'even': 82,
#  'like': 83,
#  'our': 84,
#  'who': 85,
#  'district': 86,
#  'or': 87,
#  'because': 88,
#  'now': 89,
#  'only': 90,
#  'been': 91,
#  'get': 92,
#  "'ve": 93,
#  'how': 94,
#  'time': 95,
#  'down': 96,
#  'would': 97,
#  'could': 98,
#  'did': 99,
#  'go': 100,
#  'off': 101,
#  'right': 102,
#  'gale': 103,
#  'capitol': 104,
#  'more': 105,
#  'before': 106,
#  'ca': 107,
#  'too': 108,
#  'make': 109,
#  'some': 110,
#  'had': 111,
#  'something': 112,
#  'around': 113,
#  'still': 114,
#  '!': 115,
#  'over': 116,
#  'were': 117,
#  'mother': 118,
#  'take': 119,
#  '—': 120,
#  'where': 121,
#  'look': 122,
#  "'d": 123,
#  'games': 124,
#  'other': 125,
#  'never': 126,
#  'head': 127,
#  'does': 128,
#  'their': 129,
#  'well': 130,
#  'after': 131,
#  'beetee': 132,
#  'snow': 133,
#  'maybe': 134,
#  'really': 135,
#  'your': 136,
#  'want': 137,
#  'going': 138,
#  'through': 139,
#  'face': 140,
#  'last': 141,
#  'here': 142,
#  'water': 143,
#  'away': 144,
#  'than': 145,
#  'must': 146,
#  'while': 147,
#  'people': 148,
#  'way': 149,
#  'let': 150,
#  'hand': 151,
#  'eyes': 152,
#  'myself': 153,
#  'first': 154,
#  'any': 155,
#  'johanna': 156,
#  'two': 157,
#  'since': 158,
#  'arena': 159,
#  'much': 160,
#  'president': 161,
#  'until': 162,
#  'effie': 163,
#  'good': 164,
#  'feel': 165,
#  'home': 166,
#  "'ll": 167,
#  'cinna': 168,
#  'again': 169,
#  'little': 170,
#  'tell': 171,
#  'why': 172,
#  'asks': 173,
#  'hands': 174,
#  'katniss': 175,
#  'tree': 176,
#  'find': 177,
#  'year': 178,
#  'come': 179,
#  'prim': 180,
#  'ask': 181,
#  'seems': 182,
#  'which': 183,
#  'hear': 184,
#  'keep': 185,
#  '...': 186,
#  'better': 187,
#  'few': 188,
#  'nothing': 189,
#  'thing': 190,
#  'another': 191,
#  'long': 192,
#  'left': 193,
#  'things': 194,
#  'night': 195,
#  'got': 196,
#  'voice': 197,
#  'am': 198,
#  'trying': 199,
#  'being': 200,
#  'though': 201,
#  'might': 202,
#  'tributes': 203,
#  'try': 204,
#  'hair': 205,
#  'each': 206,
#  'day': 207,
#  'alive': 208,
#  'ground': 209,
#  'enough': 210,
#  'made': 211,
#  'those': 212,
#  'should': 213,
#  'jungle': 214,
#  'very': 215,
#  'anything': 216,
#  'moment': 217,
#  'every': 218,
#  'old': 219,
#  'give': 220,
#  'turn': 221,
#  'woods': 222,
#  'remember': 223,
#  'sure': 224,
#  'dead': 225,
#  'behind': 226,
#  'everyone': 227,
#  'almost': 228,
#  'life': 229,
#  'force': 230,
#  'side': 231,
#  'room': 232,
#  'watch': 233,
#  'someone': 234,
#  'yes': 235,
#  'help': 236,
#  'always': 237,
#  'mags': 238,
#  'both': 239,
#  'said': 240,
#  'thought': 241,
#  'place': 242,
#  'takes': 243,
#  'kill': 244,
#  'others': 245,
#  'victors': 246,
#  'move': 247,
#  'family': 248,
#  'table': 249,
#  'door': 250,
#  'makes': 251,
#  'begin': 252,
#  'wiress': 253,
#  'stop': 254,
#  'gives': 255,
#  'its': 256,
#  'own': 257,
#  'rest': 258,
#  'least': 259,
#  'begins': 260,
#  '1': 261,
#  'love': 262,
#  'most': 263,
#  'blood': 264,
#  'years': 265,
#  'between': 266,
#  'next': 267,
#  'against': 268,
#  'guess': 269,
#  'square': 270,
#  'lot': 271,
#  'house': 272,
#  'arm': 273,
#  'run': 274,
#  'anyway': 275,
#  'probably': 276,
#  'under': 277,
#  'same': 278,
#  'anyone': 279,
#  '12': 280,
#  'mean': 281,
#  'ever': 282,
#  'fingers': 283,
#  'whole': 284,
#  'these': 285,
#  'girl': 286,
#  'work': 287,
#  'skin': 288,
#  'everything': 289,
#  'without': 290,
#  'new': 291,
#  'course': 292,
#  'feet': 293,
#  'need': 294,
#  'wire': 295,
#  'sleep': 296,
#  'body': 297,
#  'mind': 298,
#  'else': 299,
#  'sound': 300,
#  'hold': 301,
#  'food': 302,
#  'comes': 303,
#  'twelve': 304,
#  'woman': 305,
#  'air': 306,
#  'three': 307,
#  'white': 308,
#  'thinking': 309,
#  'wo': 310,
#  'kind': 311,
#  'looks': 312,
#  'stay': 313,
#  'reach': 314,
#  'already': 315,
#  'field': 316,
#  'train': 317,
#  'words': 318,
#  'victor': 319,
#  'open': 320,
#  'once': 321,
#  'clear': 322,
#  'hard': 323,
#  'gone': 324,
#  'bad': 325,
#  'bed': 326,
#  'start': 327,
#  'wait': 328,
#  'crowd': 329,
#  'pull': 330,
#  'sit': 331,
#  'oh': 332,
#  'show': 333,
#  'districts': 334,
#  'man': 335,
#  'rue': 336,
#  'end': 337,
#  'small': 338,
#  'death': 339,
#  'team': 340,
#  'beach': 341,
#  'happened': 342,
#  'walk': 343,
#  'peacekeepers': 344,
#  'knows': 345,
#  'point': 346,
#  'means': 347,
#  'put': 348,
#  'seen': 349,
#  'finally': 350,
#  'inside': 351,
#  'training': 352,
#  'cornucopia': 353,
#  'stand': 354,
#  "'": 355,
#  'leave': 356,
#  'real': 357,
#  'instead': 358,
#  'lips': 359,
#  'mouth': 360,
#  'use': 361,
#  'floor': 362,
#  'realize': 363,
#  'although': 364,
#  'twill': 365,
#  'far': 366,
#  'idea': 367,
#  'knife': 368,
#  'lightning': 369,
#  'arms': 370,
#  'quell': 371,
#  'talk': 372,
#  'notice': 373,
#  'mockingjay': 374,
#  'fog': 375,
#  'bit': 376,
#  'light': 377,
#  'friends': 378,
#  'best': 379,
#  'die': 380,
#  'across': 381,
#  'either': 382,
#  'along': 383,
#  'mine': 384,
#  'faces': 385,
#  'bonnie': 386,
#  'arrow': 387,
#  'knew': 388,
#  'front': 389,
#  'making': 390,
#  'eat': 391,
#  'hunger': 392,
#  'doing': 393,
#  'seem': 394,
#  'alone': 395,
#  'done': 396,
#  'morning': 397,
#  'turns': 398,
#  'dress': 399,
#  'save': 400,
#  'caesar': 401,
#  'pretty': 402,
#  'full': 403,
#  'hazelle': 404,
#  'uprising': 405,
#  'cut': 406,
#  'pain': 407,
#  'actually': 408,
#  'weapons': 409,
#  'having': 410,
#  'part': 411,
#  'together': 412,
#  'plan': 413,
#  'days': 414,
#  'goes': 415,
#  'coming': 416,
#  'killed': 417,
#  'hours': 418,
#  'sand': 419,
#  'holds': 420,
#  'bring': 421,
#  'forward': 422,
#  'ten': 423,
#  'exactly': 424,
#  'sun': 425,
#  'brutus': 426,
#  'watching': 427,
#  'wanted': 428,
#  'trees': 429,
#  'second': 430,
#  'getting': 431,
#  'such': 432,
#  'tour': 433,
#  'bread': 434,
#  'act': 435,
#  'took': 436,
#  'matter': 437,
#  'toward': 438,
#  'smile': 439,
#  'fence': 440,
#  'holding': 441,
#  'set': 442,
#  'live': 443,
#  'enobaria': 444,
#  'different': 445,
#  'clean': 446,
#  'question': 447,
#  'whatever': 448,
#  'late': 449,
#  'quickly': 450,
#  'minutes': 451,
#  'above': 452,
#  'sense': 453,
#  'shoot': 454,
#  'black': 455,
#  'father': 456,
#  'onto': 457,
#  'close': 458,
#  'wedding': 459,
#  'center': 460,
#  'slowly': 461,
#  'running': 462,
#  'fact': 463,
#  'less': 464,
#  'stuff': 465,
#  'thread': 466,
#  'hunting': 467,
#  'eight': 468,
#  'nuts': 469,
#  'half': 470,
#  'shoulder': 471,
#  'answer': 472,
#  'times': 473,
#  'sorry': 474,
#  'madge': 475,
#  'today': 476,
#  'name': 477,
#  'heart': 478,
#  'chance': 479,
#  'eye': 480,
#  'usual': 481,
#  'wonder': 482,
#  '111': 483,
#  'many': 484,
#  'may': 485,
#  'used': 486,
#  '8': 487,
#  'hope': 488,
#  'ago': 489,
#  'straight': 490,
#  'dinner': 491,
#  'tea': 492,
#  'sky': 493,
#  'safe': 494,
#  'waiting': 495,
#  'reaping': 496,
#  'fight': 497,
#  'shake': 498,
#  'television': 499,
#  'peacekeeper': 500,
#  'deep': 501,
#  'keeping': 502,
#  'sort': 503,
#  'beside': 504,
#  'told': 505,
#  'quarter': 506,
#  '4': 507,
#  'yeah': 508,
#  'during': 509,
#  'nod': 510,
#  'belt': 511,
#  'wave': 512,
#  'building': 513,
#  'blue': 514,
#  'darius': 515,
#  'world': 516,
#  'worse': 517,
#  'somehow': 518,
#  'suddenly': 519,
#  'kiss': 520,
#  'heard': 521,
#  'power': 522,
#  'prep': 523,
#  'audience': 524,
#  'okay': 525,
#  'neck': 526,
#  'came': 527,
#  'top': 528,
#  'return': 529,
#  'found': 530,
#  'lie': 531,
#  'final': 532,
#  'somewhere': 533,
#  'dark': 534,
#  'tribute': 535,
#  'game': 536,
#  'mines': 537,
#  'steps': 538,
#  'person': 539,
#  'plutarch': 540,
#  'appears': 541,
#  'taken': 542,
#  'except': 543,
#  'bag': 544,
#  'barely': 545,
#  'four': 546,
#  'soon': 547,
#  'looking': 548,
#  'circle': 549,
#  'supposed': 550,
#  'kids': 551,
#  'leaving': 552,
#  'green': 553,
#  'yards': 554,
#  'leg': 555,
#  '13': 556,
#  'hour': 557,
#  'weapon': 558,
#  'feeling': 559,
#  'step': 560,
#  'wants': 561,
#  'direction': 562,
#  'station': 563,
#  'careers': 564,
#  'thanks': 565,
#  'metal': 566,
#  'true': 567,
#  'shut': 568,
#  'himself': 569,
#  'able': 570,
#  'wish': 571,
#  'call': 572,
#  'arrows': 573,
#  'sister': 574,
#  'sounds': 575,
#  'pulls': 576,
#  'fresh': 577,
#  'word': 578,
#  'bow': 579,
#  "o'clock": 580,
#  'pin': 581,
#  'decide': 582,
#  'gold': 583,
#  'quite': 584,
#  'five': 585,
#  'portia': 586,
#  'justice': 587,
#  'ill': 588,
#  'tock': 589,
#  'victory': 590,
#  'given': 591,
#  'chest': 592,
#  'possible': 593,
#  'warm': 594,
#  'especially': 595,
#  'spot': 596,
#  'distance': 597,
#  'gamemakers': 598,
#  'also': 599,
#  'school': 600,
#  'saw': 601,
#  'cold': 602,
#  'taking': 603,
#  'clothes': 604,
#  'sight': 605,
#  'strong': 606,
#  'starts': 607,
#  'catch': 608,
#  'high': 609,
#  'big': 610,
#  'figure': 611,
#  'perhaps': 612,
#  'smell': 613,
#  'clock': 614,
#  'cameras': 615,
#  'rebellion': 616,
#  'liquor': 617,
#  'mayor': 618,
#  'talking': 619,
#  'several': 620,
#  'gave': 621,
#  'leaves': 622,
#  'moving': 623,
#  'won': 624,
#  'children': 625,
#  'knowing': 626,
#  'went': 627,
#  'hits': 628,
#  'wake': 629,
#  'follow': 630,
#  'whisper': 631,
#  'wet': 632,
#  'kitchen': 633,
#  'ready': 634,
#  'saying': 635,
#  'coal': 636,
#  'line': 637,
#  'wrong': 638,
#  'monkeys': 639,
#  'allies': 640,
#  'tick': 641,
#  'turned': 642,
#  'tears': 643,
#  'strange': 644,
#  'touch': 645,
#  'edge': 646,
#  'bright': 647,
#  'morphling': 648,
#  'lost': 649,
#  'chaff': 650,
#  'job': 651,
#  'puts': 652,
#  'window': 653,
#  'hit': 654,
#  'manage': 655,
#  'friend': 656,
#  'choice': 657,
#  'tells': 658,
#  'happens': 659,
#  'none': 660,
#  'shot': 661,
#  'believe': 662,
#  'vines': 663,
#  'hob': 664,
#  'ones': 665,
#  'besides': 666,
#  'surely': 667,
#  'minute': 668,
#  'drink': 669,
#  'large': 670,
#  'rise': 671,
#  'bird': 672,
#  'knees': 673,
#  'tonight': 674,
#  'completely': 675,
#  'standing': 676,
#  'wild': 677,
#  'herself': 678,
#  'change': 679,
#  'play': 680,
#  'care': 681,
#  'octavia': 682,
#  'happy': 683,
#  'drop': 684,
#  'bet': 685,
#  'fall': 686,
#  'sits': 687,
#  'quiet': 688,
#  'empty': 689,
#  'break': 690,
#  'maysilee': 691,
#  'fast': 692,
#  'giving': 693,
#  'yet': 694,
#  'spile': 695,
#  'protect': 696,
#  'silence': 697,
#  'weeks': 698,
#  'tightly': 699,
#  'join': 700,
#  'living': 701,
#  'attention': 702,
#  'pair': 703,
#  'stops': 704,
#  'send': 705,
#  'drag': 706,
#  'families': 707,
#  'piece': 708,
#  'hot': 709,
#  'handful': 710,
#  'throat': 711,
#  'runs': 712,
#  'birds': 713,
#  'unless': 714,
#  'lead': 715,
#  'among': 716,
#  'special': 717,
#  'immediately': 718,
#  'understand': 719,
#  'nose': 720,
#  'called': 721,
#  'catches': 722,
#  'beautiful': 723,
#  'trident': 724,
#  'cheek': 725,
#  'breath': 726,
#  'doubt': 727,
#  'meant': 728,
#  'later': 729,
#  'gets': 730,
#  'started': 731,
#  'laugh': 732,
#  'flowers': 733,
#  'brought': 734,
#  'laughing': 735,
#  'sent': 736,
#  'beyond': 737,
#  'young': 738,
#  'doors': 739,
#  'reason': 740,
#  'working': 741,
#  'nods': 742,
#  'recognize': 743,
#  'heavy': 744,
#  'longer': 745,
#  'tried': 746,
#  'opening': 747,
#  'anymore': 748,
#  'seam': 749,
#  'roof': 750,
#  'wound': 751,
#  'sitting': 752,
#  'stands': 753,
#  'town': 754,
#  'scream': 755,
#  'lose': 756,
#  'slight': 757,
#  'speak': 758,
#  'gather': 759,
#  'slightly': 760,
#  'hardly': 761,
#  'golden': 762,
#  'fish': 763,
#  'dangerous': 764,
#  'glad': 765,
#  'hundred': 766,
#  '3': 767,
#  'feels': 768,
#  'number': 769,
#  'position': 770,
#  'short': 771,
#  'dressed': 772,
#  'attack': 773,
#  'pink': 774,
#  'staring': 775,
#  'trouble': 776,
#  'strip': 777,
#  'gloves': 778,
#  'seeing': 779,
#  'noon': 780,
#  'lets': 781,
#  'hurt': 782,
#  'climb': 783,
#  'simply': 784,
#  'clearly': 785,
#  'stopped': 786,
#  'thank': 787,
#  'meet': 788,
#  'keeps': 789,
#  'lift': 790,
#  'filled': 791,
#  'stage': 792,
#  'impossible': 793,
#  'meal': 794,
#  'starting': 795,
#  'entirely': 796,
#  'flesh': 797,
#  'bodies': 798,
#  'pack': 799,
#  'outside': 800,
#  'makeup': 801,
#  'quietly': 802,
#  'rebels': 803,
#  'sharp': 804,
#  'berries': 805,
#  'soft': 806,
#  'couple': 807,
#  'worry': 808,
#  'bottle': 809,
#  'order': 810,
#  'venia': 811,
#  'thin': 812,
#  'free': 813,
#  'swim': 814,
#  'orange': 815,
#  'eating': 816,
#  'began': 817,
#  'land': 818,
#  'conversation': 819,
#  'lives': 820,
#  'cray': 821,
#  'caught': 822,
#  'boots': 823,
#  'red': 824,
#  'good-bye': 825,
#  'glass': 826,
#  'wall': 827,
#  'brings': 828,
#  'form': 829,
#  'color': 830,
#  'trust': 831,
#  'smoke': 832,
#  'case': 833,
#  'shoes': 834,
#  'killing': 835,
#  'fighting': 836,
#  'everybody': 837,
#  'speech': 838,
#  'works': 839,
#  'died': 840,
#  'ourselves': 841,
#  'escape': 842,
#  'easy': 843,
#  'perfect': 844,
#  'medicine': 845,
#  'nightmares': 846,
#  'interview': 847,
#  'money': 848,
#  'imagine': 849,
#  'hanging': 850,
#  'spent': 851,
#  'forget': 852,
#  'obviously': 853,
#  'hovercraft': 854,
#  'lake': 855,
#  'rolls': 856,
#  'great': 857,
#  'branches': 858,
#  'midnight': 859,
#  'itself': 860,
#  'trunk': 861,
#  'silent': 862,
#  'calm': 863,
#  'slow': 864,
#  'appear': 865,
#  'information': 866,
#  'turning': 867,
#  'jumpsuit': 868,
#  'past': 869,
#  'sink': 870,
#  'stare': 871,
#  'easily': 872,
#  'grip': 873,
#  'agree': 874,
#  'sick': 875,
#  'rain': 876,
#  'parachute': 877,
#  'draw': 878,
#  'forced': 879,
#  'party': 880,
#  'possibly': 881,
#  'thinks': 882,
#  'gift': 883,
#  'pale': 884,
#  'closer': 885,
#  'fear': 886,
#  'thick': 887,
#  'simple': 888,
#  'usually': 889,
#  'afraid': 890,
#  'stick': 891,
#  'happen': 892,
#  'guard': 893,
#  'neither': 894,
#  'carry': 895,
#  'sees': 896,
#  'coil': 897,
#  'sets': 898,
#  'moss': 899,
#  'enemy': 900,
#  'stupid': 901,
#  'boy': 902,
#  'moments': 903,
#  'fun': 904,
#  'sign': 905,
#  'cover': 906,
#  'village': 907,
#  'moonlight': 908,
#  'below': 909,
#  'huge': 910,
#  'using': 911,
#  'cry': 912,
#  'streets': 913,
#  ':': 914,
#  'become': 915,
#  'public': 916,
#  'tiny': 917,
#  'determined': 918,
#  'months': 919,
#  'raise': 920,
#  'deadly': 921,
#  'paint': 922,
#  'hate': 923,
#  'car': 924,
#  'pass': 925,
#  'spring': 926,
#  'ear': 927,
#  'ahead': 928,
#  'worked': 929,
#  'camera': 930,
#  '11': 931,
#  'known': 932,
#  'drops': 933,
#  'nice': 934,
#  'dining': 935,
#  'hang': 936,
#  'pause': 937,
#  'thresh': 938,
#  'naked': 939,
#  'week': 940,
#  'panem': 941,
#  'meeting': 942,
#  'beauty': 943,
#  'softly': 944,
#  'shell': 945,
#  'plans': 946,
#  'heavensbee': 947,
#  'hoping': 948,
#  'funny': 949,
#  'round': 950,
#  'plants': 951,
#  'terrible': 952,
#  'dying': 953,
#  'anthem': 954,
#  'sunlight': 955,
#  'comment': 956,
#  'elevator': 957,
#  'shock': 958,
#  'greasy': 959,
#  'awful': 960,
#  'sae': 961,
#  'source': 962,
#  'yourself': 963,
#  'city': 964,
#  'dresses': 965,
#  'thirteen': 966,
#  'cannon': 967,
#  'smiles': 968,
#  'box': 969,
#  'view': 970,
#  'walking': 971,
#  'windows': 972,
#  'eyebrows': 973,
#  'orders': 974,
#  'aside': 975,
#  'gray': 976,
#  'throw': 977,
#  'deal': 978,
#  'playing': 979,
#  'asked': 980,
#  'survive': 981,
#  'problem': 982,
#  'slide': 983,
#  'seeder': 984,
#  'exchange': 985,
#  'fine': 986,
#  'calls': 987,
#  'trap': 988,
#  'miss': 989,
#  'gloss': 990,
#  'ears': 991,
#  'insects': 992,
#  '2': 993,
#  'bolt': 994,
#  'cloth': 995,
#  'weight': 996,
#  'hunt': 997,
#  'carefully': 998,
#  'quick': 999,
#  ...}

# %% [markdown]
# Now we pick a word from the corpus (remember this is lowercase) and see what the vector associated with it is. This is not human-readable, but it's this list (array) of numbers that helps us define the word in context.

# %%
model.wv.get_vector("capitol", norm=True)
# Out:
# array([-0.01423638,  0.02324909,  0.07218862, -0.05359417,  0.06134805,
#        -0.0790454 ,  0.01130053,  0.19268242, -0.094578  , -0.06153402,
#        -0.06871964, -0.09467302, -0.04575939,  0.07142065, -0.01867204,
#        -0.03969252, -0.01570899,  0.02682004, -0.03472603, -0.16276717,
#        -0.00262302,  0.00935201,  0.07381377, -0.1005934 ,  0.05439118,
#        -0.05676807, -0.08133087, -0.01455954, -0.13219318,  0.00089247,
#         0.14137185,  0.02237535,  0.07133125, -0.12888616,  0.01979403,
#         0.08040908,  0.05272003, -0.06338643, -0.00508615, -0.1855933 ,
#         0.06771424, -0.1337245 , -0.06391485, -0.0336    ,  0.18015264,
#        -0.01544141, -0.13518542, -0.09090749,  0.07163714,  0.03487578,
#         0.11141016, -0.17460413, -0.02648918, -0.03772881, -0.09908996,
#         0.03897305, -0.0192244 , -0.02271508, -0.1840031 ,  0.14274359,
#         0.11198664,  0.04306361,  0.1423507 , -0.00095882, -0.13506305,
#         0.10134505,  0.11961561,  0.17149773, -0.12989928,  0.24048203,
#        -0.02689156,  0.12068822,  0.18159479,  0.01334876,  0.14743291,
#         0.06833546,  0.0079123 , -0.03586668, -0.05490749, -0.02112536,
#         0.02188782, -0.0532005 , -0.248157  ,  0.15071867, -0.07842042,
#        -0.00412842,  0.00583178,  0.06871744,  0.17757186,  0.1162913 ,
#         0.18071097,  0.09704681,  0.05187044, -0.0389085 ,  0.198971  ,
#         0.11001627,  0.12211671, -0.13103214, -0.00932628, -0.05934801],
#       dtype=float32)

# %% [markdown]
# Find all the words most similar to a word you've chosen. Notice that this similarity is not the same as the vector representation above.
#
# After you run this cell, make a note of the top 5 words. Go back and change the number of words in the vector and re-run the cells in between. Did it change?

# %%
model.wv.most_similar('capitol')
# Out:
# [('one', 0.9927374720573425),
#  ('us', 0.990419864654541),
#  ('arena', 0.9895527958869934),
#  ('last', 0.986949622631073),
#  ('has', 0.9863299131393433),
#  ('games', 0.9858510494232178),
#  ('for', 0.9806182384490967),
#  ('life', 0.9805378317832947),
#  ('who', 0.9796977043151855),
#  ('night', 0.9795113801956177)]

# %% [markdown]
# Now see how similar some words are. Change these words if you change the text.

# %%
model.wv.similarity('katniss', 'girl')
# Out:
# 0.84514725

# %%
model.wv.similarity('peeta', 'home')
# Out:
# 0.9308819

# %% [markdown]
# Finally visualize the result. There's a lot of code here, it's really just for visualization. The first part is the dimensionality reduction (using t-SNE). The second part puts it on a visualization.
#
#
# Spend more time exploring the visualization than breaking down the code.
#
# The visualization that results is very hard to see. If you are in a Jupyter Notebook, there are tools in the upper right corner of the cell that has the visualization in it (they appear on hover). You can zoom in on the visualization to see the words and the relationships between the words.

# %%
def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    # extract the words & their vectors, as numpy arrays
    vectors = np.asarray(model.wv.vectors)
    labels = np.asarray(model.wv.index_to_key)  # fixed-width numpy strings

    # reduce using t-SNE
    tsne = TSNE(n_components=num_dimensions, random_state=0)
    vectors = tsne.fit_transform(vectors)

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels


x_vals, y_vals, labels = reduce_dimensions(model)

# %%
def plot_with_plotly(x_vals, y_vals, labels, plot_in_notebook=True):
    from plotly.offline import init_notebook_mode, iplot, plot
    import plotly.graph_objs as go

    trace = go.Scatter(x=x_vals, y=y_vals, mode='text', text=labels)
    data = [trace]

    if plot_in_notebook:
        init_notebook_mode(connected=True)
        iplot(data, filename='word-embedding-plot')
    else:
        plot(data, filename='word-embedding-plot.html')


def plot_with_matplotlib(x_vals, y_vals, labels):
    import matplotlib.pyplot as plt
    import random

    random.seed(0)

    plt.figure(figsize=(12, 12))
    plt.scatter(x_vals, y_vals)

    #
    # Label randomly subsampled 25 data points
    #
    indices = list(range(len(labels)))
    selected_indices = random.sample(indices, 25)
    for i in selected_indices:
        plt.annotate(labels[i], (x_vals[i], y_vals[i]))

try:
    get_ipython()
except Exception:
    plot_function = plot_with_matplotlib
else:
    plot_function = plot_with_plotly

plot_function(x_vals, y_vals, labels)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="0b9ea6dd-4cbd-45b3-a51b-5215d0386d50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b9ea6dd-4cbd-45b3-a51b-5215d0386d50")) {                    Plotly.newPlot(                        "0b9ea6dd-4cbd-45b3-a51b-5215d0386d50",                        [{"mode":"text","text":[".",",","the","i","to","and","a","of","``","''","'s","it","in","my","he","that","but","n't","me","?","on","with","you","we","for","is","peeta","his","be","as","do","at","have","they","says","from","out","what","him","so","her","up","can","fire","was","she","not","this","no","if","there","catching","are","one","collins","all","-","suzanne","p","g","e","|","'m","know","say","about","into","when","us","haymitch","just","finnick","will","them","back","has","think","then","by","see","an","'re","even","like","our","who","district","or","because","now","only","been","get","'ve","how","time","down","would","could","did","go","off","right","gale","capitol","more","before","ca","too","make","some","had","something","around","still","!","over","were","mother","take","\u2014","where","look","'d","games","other","never","head","does","their","well","after","beetee","snow","maybe","really","your","want","going","through","face","last","here","water","away","than","must","while","people","way","let","hand","eyes","myself","first","any","johanna","two","since","arena","much","president","until","effie","good","feel","home","'ll","cinna","again","little","tell","why","asks","hands","katniss","tree","find","year","come","prim","ask","seems","which","hear","keep","...","better","few","nothing","thing","another","long","left","things","night","got","voice","am","trying","being","though","might","tributes","try","hair","each","day","alive","ground","enough","made","those","should","jungle","very","anything","moment","every","old","give","turn","woods","remember","sure","dead","behind","everyone","almost","life","force","side","room","watch","someone","yes","help","always","mags","both","said","thought","place","takes","kill","others","victors","move","family","table","door","makes","begin","wiress","stop","gives","its","own","rest","least","begins","1","love","most","blood","years","between","next","against","guess","square","lot","house","arm","run","anyway","probably","under","same","anyone","12","mean","ever","fingers","whole","these","girl","work","skin","everything","without","new","course","feet","need","wire","sleep","body","mind","else","sound","hold","food","comes","twelve","woman","air","three","white","thinking","wo","kind","looks","stay","reach","already","field","train","words","victor","open","once","clear","hard","gone","bad","bed","start","wait","crowd","pull","sit","oh","show","districts","man","rue","end","small","death","team","beach","happened","walk","peacekeepers","knows","point","means","put","seen","finally","inside","training","cornucopia","stand","'","leave","real","instead","lips","mouth","use","floor","realize","although","twill","far","idea","knife","lightning","arms","quell","talk","notice","mockingjay","fog","bit","light","friends","best","die","across","either","along","mine","faces","bonnie","arrow","knew","front","making","eat","hunger","doing","seem","alone","done","morning","turns","dress","save","caesar","pretty","full","hazelle","uprising","cut","pain","actually","weapons","having","part","together","plan","days","goes","coming","killed","hours","sand","holds","bring","forward","ten","exactly","sun","brutus","watching","wanted","trees","second","getting","such","tour","bread","act","took","matter","toward","smile","fence","holding","set","live","enobaria","different","clean","question","whatever","late","quickly","minutes","above","sense","shoot","black","father","on ...

# %% [markdown]
# ## Part 2 : GloVe

# %% [markdown]
# **UNZIP THE GLOVE.6B.ZIP FOLDER ASSOCIATED WITH THIS LAB**

# %%
import numpy as np
from scipy import spatial
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %% [markdown]
# There are a few files in the `glove/6B` folder. These are the embeddings. You can open them and see them in any text editor. 50d is the smallest one. Each word has 50 dimensions. This means it is defined in terms of 50 other words.
#
# This lab uses the 100d file. If it's running slower than you like, feel free to use 50d instead. If you want more accurate word relationships, use one of the larger files.

# %%
#establish an empty dictionary
embeddings_dict = {}

#open the file and read it into the dictionary
with open("glove.6B/glove.6B.100d.txt", 'r', encoding="utf-8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

# %%
#find the Euclidean distance between the vectors for words and 1 or more other words.
#sort the resulting word distances.
def find_closest_embeddings(embedding):
    return sorted(embeddings_dict.keys(), key=lambda word: 
                  spatial.distance.euclidean(embeddings_dict[word], embedding))

# %% [markdown]
# Now try it out - pick some words to experiment with. This experimentation section is the most important part of Part 2.

# %%
print(find_closest_embeddings(
    embeddings_dict["dog"]
)[:20])
# Out:
# ['dog', 'cat', 'dogs', 'puppy', 'pet', 'horse', 'pig', 'cats', 'animal', 'rabbit', 'boy', 'goat', 'monkey', 'rat', 'hound', 'breed', 'canine', 'sled', 'pets', 'puppies']

# %%
print(find_closest_embeddings(
    embeddings_dict["cat"]
)[:20])
# Out:
# ['cat', 'dog', 'rabbit', 'cats', 'monkey', 'puppy', 'pet', 'dogs', 'rat', 'mouse', 'spider', 'elephant', 'ghost', 'pig', 'monster', 'ape', 'parrot', 'squirrel', 'kitten', 'hound']

# %% [markdown]
# Now pick 2 words and see how it changes. Note that the `+` actually indicates that the vectors are being added. This may have slightly unexpected results.

# %%
print(find_closest_embeddings(
    embeddings_dict["dog"] + embeddings_dict["cat"]
)[:20])
# Out:
# ['dog', 'cat', 'dogs', 'pet', 'rabbit', 'horse', 'puppy', 'cats', 'monkey', 'animal', 'mouse', 'boy', 'pig', 'rat', 'bird', 'baby', 'duck', 'snake', 'cow', 'goat']

# %% [markdown]
# See what happens with a 3rd. These embeddings are basically being triangulated - and this list is what is nearest to the center of these 3 points.

# %%
print(find_closest_embeddings(
    embeddings_dict["dog"] + embeddings_dict["cat"] + embeddings_dict["pet"]
)[:20])
# Out:
# ['dog', 'pet', 'cat', 'dogs', 'animal', 'cats', 'pets', 'animals', 'puppy', 'baby', 'rabbit', 'mouse', 'cow', 'monkey', 'bird', 'horse', 'pig', 'rat', 'boy', 'duck']

# %% [markdown]
# Now transform the dictionary into an array so that we can do dimensionality reduction so we can visualize the words

# %%
words =  list(embeddings_dict.keys())
vectors = [embeddings_dict[word] for word in words]
X = np.asarray(vectors)

# %% [markdown]
# Now do the dimensionality reduction with t-SNE.

# %%
tsne = TSNE(n_components=2, random_state=0)
Y = tsne.fit_transform(X[:1000])

# %% [markdown]
# Plot the points

# %%
plt.scatter(Y[:, 0], Y[:, 1])

# %% [markdown]
# Annotate a few of the words.

# %%
for label, x, y in zip(words, X[:, 0], Y[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords="offset points")
plt.show()
